# %% [markdown]
# <a href="https://colab.research.google.com/github/Sawarijamgaonkar/computer_vision/blob/main/histogram_equalisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install opencv-python
import cv2
import matplotlib.pyplot as plt
#a=c2.imread()
from google.colab.patches import cv2_imshow
a=cv2.imread('/content/image1.jpeg')
print(a)
cv2_imshow(a)
gray=cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
print(gray)
cv2_imshow(gray)
b=cv2.equalizeHist(gray)
cv2_imshow(b)
#hist1=cv2.calcHist([a],[0],None,[256],[256,0])
#hist2=cv2.calcHist([b],[0],None,[256],[256,0])
#plt.subplot(221),plt.plot(hist1)
#plt.subplot(222),plt.plot(hist2)
#result=np.hstack(a,)
#cv2_imshow(result)
# Out:
# [[[167 167 167]
#   [162 162 162]
#   [152 152 152]
#   ...
#   [ 71  71  71]
#   [ 67  67  67]
#   [ 73  73  73]]
#
#  [[146 146 146]
#   [138 138 138]
#   [124 124 124]
#   ...
#   [ 72  72  72]
#   [ 71  71  71]
#   [ 73  73  73]]
#
#  [[121 121 121]
#   [112 112 112]
#   [ 98  98  98]
#   ...
#   [ 73  73  73]
#   [ 74  74  74]
#   [ 73  73  73]]
#
#  ...
#
#  [[191 191 191]
#   [191 191 191]
#   [190 190 190]
#   ...
#   [187 187 187]
#   [187 187 187]
#   [187 187 187]]
#
#  [[191 191 191]
#   [191 191 191]
#   [190 190 190]
#   ...
#   [187 187 187]
#   [187 187 187]
#   [187 187 187]]
#
#  [[191 191 191]
#   [191 191 191]
#   [190 190 190]
#   ...
#   [187 187 187]
#   [187 187 187]
#   [187 187 187]]]
# <PIL.Image.Image image mode=RGB size=281x180>
# [[167 162 152 ...  71  67  73]
#  [146 138 124 ...  72  71  73]
#  [121 112  98 ...  73  74  73]
#  ...
#  [191 191 190 ... 187 187 187]
#  [191 191 190 ... 187 187 187]
#  [191 191 190 ... 187 187 187]]
# ...
